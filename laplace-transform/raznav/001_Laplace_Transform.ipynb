# %% [markdown]
# - **Name:** Navales Razel M.
# - **Term:** Term 3, AY24-25

# %% [markdown]
# ##### Required Python Packages
# Run the following applications once if they are not yet installed in your Python environment:

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\naval\anaconda3\lib\site-packages (2.3.5)

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\naval\anaconda3\lib\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\naval\anaconda3\lib\site-packages (from scipy) (2.3.5)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\naval\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\naval\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\naval\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install panda
# Out:
# Requirement already satisfied: panda in c:\users\naval\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: setuptools in c:\users\naval\anaconda3\lib\site-packages (from panda) (80.9.0)
# Requirement already satisfied: requests in c:\users\naval\anaconda3\lib\site-packages (from panda) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\naval\anaconda3\lib\site-packages (from requests->panda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\naval\anaconda3\lib\site-packages (from requests->panda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\naval\anaconda3\lib\site-packages (from requests->panda) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naval\anaconda3\lib\site-packages (from requests->panda) (2026.1.4)

# %%
# !pip install gekko
# Out:
# Requirement already satisfied: gekko in c:\users\naval\anaconda3\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\naval\anaconda3\lib\site-packages (from gekko) (2.3.5)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\naval\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\naval\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\naval\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\naval\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\naval\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in c:\users\naval\anaconda3\lib\site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\naval\anaconda3\lib\site-packages (from sympy) (1.3.0)

# %% [markdown]
# ### Machine Problem 001: Laplace Transforms and Sympy
#
# Laplace transforms convert a function $f(t)$ in the time domain into function in the Laplace domain $F(s)$.
#
# $F(s) = \mathcal{L}\left(f(t)\right) = \int_0^\infty f(t)e^{-s\,t}dt$
#
# The SymPy library is a symbolic mathematics library written for Python that can be used to perform analytical calculations. This library can be very useful for control system design and analysis.

# %% [markdown]
# ### Table of Common Laplace Transforms
# Mathematicians have developed tables of commonly used Laplace transforms. Here is summary table with a few of the entries that will be most common for analysis of linear differential equations.
#
# | **Item no.** | **f(t)**                | **F(s)**                           |
# |--------------|-------------------------|------------------------------------|
# | 1.           | $ \delta(t) $           | $ 1 $                              |
# | 2.           | $ u(t) $                | $ \frac{1}{s} $                    |
# | 3.           | $ tu(t) $               | $ \frac{1}{s^2} $                  |
# | 4.           | $ t^n u(t) $            | $ \frac{n!}{s^{n+1}} $             |
# | 5.           | $ e^{-at}u(t) $         | $ \frac{1}{s + a} $                |
# | 6.           | $ \sin(\omega t)u(t) $  | $ \frac{\omega}{s^2 + \omega^2} $  |
# | 7.           | $ \cos(\omega t)u(t) $  | $ \frac{s}{s^2 + \omega^2} $       |

# %%
import sympy as sym
from sympy.abc import s,t,u,x,y,z,a,b,c,k
from sympy.integrals import laplace_transform

# %%
# For pretty  printing
sym.init_printing()

# %%
# Define variables for time 't' and complex variable 's'
# t = sym.symbols('t', real=True)
# s = sym.symbols('s')

# Define a constant:
# a = sym.symbols('a', real=True, positive=True)

# %% [markdown]
# 1. Evaluate:
#
# $$ \mathcal{L}\{\delta(t)\} = 1 $$
#
# As an example of the Laplace transform, consider a constant $1$. The function $f(t) = 1$ and the following expression is integrated.
#
# $\mathcal{L}(1)=\int_0^\infty 1 \, e^{-s\,t} dt = -\frac{1}{s}e^{-s\,t} \biggr\rvert_0^\infty = 0 - \left(-\frac{1}{s} \right) = \frac{1}{s}$
#
# Notice that the derived value for a constant $1$ is the unit step function with $f(t)=1$ where a signal output changes from 0 to 1 at $time=0$.

# %%
# Define the time domain function:
f1 = 1
f1
# Out:
# 1

# %%
# Compute the Laplace Transform:
f1s = laplace_transform(f1, t, s, noconds=True)
f1s
# Out:
# 1
# ─
# s

# %% [markdown]
# 2. Evaluate:
#
# $$ \mathcal{L}\{u(t)\} = \frac{1}{s} $$
# $$ \mathcal{L}\{t\} = \frac{1}{s^2} $$

# %%
# Define the time domain function:
f2 = t
f2
# Out:
# t

# %%
# Compute the Laplace Transform:
f2s = laplace_transform(f2, t, s, noconds=True)
f2s
# Out:
# 1
# ──
#  2
# s

# %% [markdown]
# 3. Evaluate:
# $$ \mathcal{L}\{tu(t)\} = \frac{1}{s^2} $$
# $$ \mathcal{L}\{5t\} = \frac{5}{s^2} $$

# %%
# Laplace transform (t->s)
U = laplace_transform(5*t, t, s)
U[0]
# Out:
# 5
# ──
#  2
# s

# %% [markdown]
# 4. Evaluate:
#
# $$ \mathcal{L}\{t^n u(t)\} = \frac{n!}{s^{n+1}} $$
# $$ \mathcal{L}\{t^2\} = \frac{2}{s^{3}} $$

# %%
# Define the time domain function:
f4 = t**2
f4
# Out:
#  2
# t

# %%
# Compute the Laplace Transform:
f4s = laplace_transform(f4, t, s, noconds=True)
f4s
# Out:
# 2
# ──
#  3
# s

# %% [markdown]
# 5. Evaluate:
#
# $$ \mathcal{L}\{e^{-at}u(t)\} = \frac{1}{s + a} $$
# Solution:
# $$ \mathcal{L}\{e^{-at}\} = \int_0^\infty \, e^{-a\,t} e^{-s\,t} dt $$
# $$ = \int_0^\infty \, e^{-(s+a)\,t} dt $$
# $$ = \frac{e^{-(s+a)t}}{-(s+a)} \biggr\rvert_0^\infty $$
# $$ = 0 - \left(-\frac{1}{s+a} \right) = \frac{1}{s+a} $$

# %%
# Define the time domain function:
f5 = sym.exp(-a*t)
f5
# Out:
#  -a⋅t
# ℯ

# %%
# Compute the Laplace Transform:
f5s = laplace_transform(f5, t, s, noconds=True)
f5s
# Out:
#   1
# ─────
# a + s

# %% [markdown]
# 6. Evaluate:
#
# $$ \mathcal{L}\{\sin(\omega t)u(t)\} = \frac{\omega}{s^2 + \omega^2} $$
# $$ \mathcal{L}\{\sin(4t)\} = \frac{4}{s^2 + 16} $$

# %%
# Define the time domain function:
f6 = sym.sin(4*t)
f6
# Out:
# sin(4⋅t)

# %%
# Compute the Laplace Transform:
f6s = laplace_transform(f6, t, s, noconds=True)
f6s
# Out:
#    4
# ───────
#  2
# s  + 16

# %% [markdown]
# 7. Evaluate:
#
# $$ \mathcal{L}\{\cos(\omega t)u(t)\} = \frac{s}{s^2 + \omega^2} $$
# $$ \mathcal{L}\{\cos(\frac{t}{2})\} = \frac{s}{s^2 + \frac{1}{4}} $$

# %%
# Define the time domain function:
f7 = sym.cos(t/2)
f7
# Out:
#    ⎛t⎞
# cos⎜─⎟
#    ⎝2⎠

# %%
# Compute the Laplace Transform:
f7s = laplace_transform(f7, t, s, noconds=True)
f7s
# Out:
#   s
# ──────
#  2   1
# s  + ─
#      4
