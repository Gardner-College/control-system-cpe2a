# %% [markdown]
# - **Name:** Asid, Jheboy B.
# - **Term:** Term 3, AY24-25

# %% [markdown]
# ##### Required Python Packages
# Run the following applications once if they are not yet installed in your Python environment:

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (2.4.4)

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from scipy) (2.4.4)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.9-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.2 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.2 MB 3.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.2 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.2 MB 3.7 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.2 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.2 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 3.2 MB/s  0:00:02
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.8 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.3 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 1.6 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/12.3 MB 1.6 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/12.3 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.3 MB 1.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/12.3 MB 1.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/12.3 MB 1.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.8/12.3 MB 1.2 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/12.3 MB 1.2 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/12.3 MB 1.3 MB/s eta 0:00:08
#    --------- ------------------------------ 2.9/12.3 MB 1.3 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.1/12.3 MB 1.3 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.7/12.3 MB 1.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.0/12.3 MB 1.7 MB/s eta 0:00:05
#    --------------------- ------------------ 6.6/12.3 MB 2.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.9/12.3 MB 2.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.0/12.3 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 3.5 MB/s  0:00:03
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ------------- -------------------------- 2.4/7.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.0/7.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.1 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 10.7 MB/s  0:00:00
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    ---------- ----------------------------- 2/8 [numpy]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    -------------------- ------------------- 4/8 [fonttools]
#    ------------------------------ --------- 6/8 [contourpy]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [matplotlib]
#    ---------------------------------------- 8/8 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 numpy-2.4.4 pillow-12.2.0 pyparsing-3.3.2

# %%
# !pip install panda
# Out:
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from panda) (82.0.1)
# Collecting requests (from panda)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests->panda)
#   Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests->panda)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests->panda)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests->panda)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp313-cp313-win_amd64.whl (158 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Building wheels for collected packages: panda
#   Building wheel for panda (pyproject.toml): started
#   Building wheel for panda (pyproject.toml): finished with status 'done'
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7295 sha256=24c40914ccf21e006d36ac9a13521a2604f3cd0174d04cb1c89a7c0f3cbb37da
#   Stored in directory: c:\users\jheboy\appdata\local\pip\cache\wheels\53\7c\f7\d3267739bc9dfdfc43724391337c9955e7d5b5830888d735e3
# Successfully built panda
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests, panda
#
#    ---------------------------------------- 0/6 [urllib3]
#    ------ --------------------------------- 1/6 [idna]
#    -------------------- ------------------- 3/6 [certifi]
#    --------------------------------- ------ 5/6 [panda]
#    ---------------------------------------- 6/6 [panda]
#
# Successfully installed certifi-2026.4.22 charset_normalizer-3.4.7 idna-3.13 panda-0.3.1 requests-2.33.1 urllib3-2.7.0

# %%
# !pip install gekko
# Out:
# Collecting gekko
#   Downloading gekko-1.3.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.8 in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from gekko) (2.4.4)
# Downloading gekko-1.3.2-py3-none-any.whl (13.2 MB)
#    ---------------------------------------- 0.0/13.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/13.2 MB 10.9 MB/s eta 0:00:02
#    --------------- ------------------------ 5.2/13.2 MB 13.3 MB/s eta 0:00:01
#    ------------------------ --------------- 8.1/13.2 MB 13.6 MB/s eta 0:00:01
#    --------------------------------- ------ 11.0/13.2 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.2/13.2 MB 13.4 MB/s  0:00:01
# Installing collected packages: gekko
# Successfully installed gekko-1.3.2

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Jheboy\anaconda3\envs\control-system-cpe2a\Lib\site-packages (from scikit-learn) (2.4.4)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.0 MB 12.5 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.0 MB 8.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 9.7 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/36.5 MB 12.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.5/36.5 MB 10.8 MB/s eta 0:00:03
#    -------- ------------------------------- 7.3/36.5 MB 11.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.0/36.5 MB 12.1 MB/s eta 0:00:03
#    -------------- ------------------------- 13.1/36.5 MB 12.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 15.7/36.5 MB 12.8 MB/s eta 0:00:02
#    ------------------- -------------------- 17.8/36.5 MB 12.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.0/36.5 MB 12.5 MB/s eta 0:00:02
#    -------------------------- ------------- 23.9/36.5 MB 12.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 26.0/36.5 MB 12.4 MB/s eta 0:00:01
#    ------------------------------ --------- 27.5/36.5 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.1/36.5 MB 12.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.5/36.5 MB 12.0 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.5 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 11.8 MB/s  0:00:03
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.3 MB 14.2 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.3 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 11.6 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 9.9 MB/s  0:00:00
# Installing collected packages: mpmath, sympy
#
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    ---------------------------------------- 2/2 [sympy]
#
# Successfully installed mpmath-1.3.0 sympy-1.14.0

# %% [markdown]
# ### Machine Problem 001: Laplace Transforms and Sympy
#
# Laplace transforms convert a function $f(t)$ in the time domain into function in the Laplace domain $F(s)$.
#
# $F(s) = \mathcal{L}\left(f(t)\right) = \int_0^\infty f(t)e^{-s\,t}dt$
#
# The SymPy library is a symbolic mathematics library written for Python that can be used to perform analytical calculations. This library can be very useful for control system design and analysis.

# %% [markdown]
# ### Table of Common Laplace Transforms
# Mathematicians have developed tables of commonly used Laplace transforms. Here is summary table with a few of the entries that will be most common for analysis of linear differential equations.
#
# | **Item no.** | **f(t)**                | **F(s)**                           |
# |--------------|-------------------------|------------------------------------|
# | 1.           | $ \delta(t) $           | $ 1 $                              |
# | 2.           | $ u(t) $                | $ \frac{1}{s} $                    |
# | 3.           | $ tu(t) $               | $ \frac{1}{s^2} $                  |
# | 4.           | $ t^n u(t) $            | $ \frac{n!}{s^{n+1}} $             |
# | 5.           | $ e^{-at}u(t) $         | $ \frac{1}{s + a} $                |
# | 6.           | $ \sin(\omega t)u(t) $  | $ \frac{\omega}{s^2 + \omega^2} $  |
# | 7.           | $ \cos(\omega t)u(t) $  | $ \frac{s}{s^2 + \omega^2} $       |

# %%
import sympy as sym
from sympy.abc import s,t,u,x,y,z,a,b,c,k
from sympy.integrals import laplace_transform

# %%
# For pretty  printing
sym.init_printing()

# %%
# Define variables for time 't' and complex variable 's'
# t = sym.symbols('t', real=True)
# s = sym.symbols('s')

# Define a constant:
# a = sym.symbols('a', real=True, positive=True)

# %% [markdown]
# 1. Evaluate:
#
# $$ \mathcal{L}\{\delta(t)\} = 1 $$
#
# As an example of the Laplace transform, consider a constant $1$. The function $f(t) = 1$ and the following expression is integrated.
#
# $\mathcal{L}(1)=\int_0^\infty 1 \, e^{-s\,t} dt = -\frac{1}{s}e^{-s\,t} \biggr\rvert_0^\infty = 0 - \left(-\frac{1}{s} \right) = \frac{1}{s}$
#
# Notice that the derived value for a constant $1$ is the unit step function with $f(t)=1$ where a signal output changes from 0 to 1 at $time=0$.

# %%
# Define the time domain function:
f1 = 1
f1
# Out:
# 1

# %%
# Compute the Laplace Transform:
f1s = laplace_transform(f1, t, s, noconds=True)
f1s
# Out:
# 1
# ─
# s

# %% [markdown]
# 2. Evaluate:
#
# $$ \mathcal{L}\{u(t)\} = \frac{1}{s} $$
# $$ \mathcal{L}\{t\} = \frac{1}{s^2} $$

# %%
# Define the time domain function:
f2 = t
f2
# Out:
# t

# %%
# Compute the Laplace Transform:
f2s = laplace_transform(f2, t, s, noconds=True)
f2s
# Out:
# 1
# ──
#  2
# s

# %% [markdown]
# 3. Evaluate:
# $$ \mathcal{L}\{tu(t)\} = \frac{1}{s^2} $$
# $$ \mathcal{L}\{5t\} = \frac{5}{s^2} $$

# %%
# Laplace transform (t->s)
U = laplace_transform(5*t, t, s)
U[0]
# Out:
# 5
# ──
#  2
# s

# %% [markdown]
# 4. Evaluate:
#
# $$ \mathcal{L}\{t^n u(t)\} = \frac{n!}{s^{n+1}} $$
# $$ \mathcal{L}\{t^2\} = \frac{2}{s^{3}} $$

# %%
# Define the time domain function:
f4 = t**2
f4
# Out:
#  2
# t

# %%
# Compute the Laplace Transform:
f4s = laplace_transform(f4, t, s, noconds=True)
f4s
# Out:
# 2
# ──
#  3
# s

# %% [markdown]
# 5. Evaluate:
#
# $$ \mathcal{L}\{e^{-at}u(t)\} = \frac{1}{s + a} $$
# Solution:
# $$ \mathcal{L}\{e^{-at}\} = \int_0^\infty \, e^{-a\,t} e^{-s\,t} dt $$
# $$ = \int_0^\infty \, e^{-(s+a)\,t} dt $$
# $$ = \frac{e^{-(s+a)t}}{-(s+a)} \biggr\rvert_0^\infty $$
# $$ = 0 - \left(-\frac{1}{s+a} \right) = \frac{1}{s+a} $$

# %%
# Define the time domain function:
f5 = sym.exp(-a*t)
f5
# Out:
#  -a⋅t
# ℯ

# %%
# Compute the Laplace Transform:
f5s = laplace_transform(f5, t, s, noconds=True)
f5s
# Out:
#   1
# ─────
# a + s

# %% [markdown]
# 6. Evaluate:
#
# $$ \mathcal{L}\{\sin(\omega t)u(t)\} = \frac{\omega}{s^2 + \omega^2} $$
# $$ \mathcal{L}\{\sin(4t)\} = \frac{4}{s^2 + 16} $$

# %%
# Define the time domain function:
f6 = sym.sin(4*t)
f6
# Out:
# sin(4⋅t)

# %%
# Compute the Laplace Transform:
f6s = laplace_transform(f6, t, s, noconds=True)
f6s
# Out:
#    4
# ───────
#  2
# s  + 16

# %% [markdown]
# 7. Evaluate:
#
# $$ \mathcal{L}\{\cos(\omega t)u(t)\} = \frac{s}{s^2 + \omega^2} $$
# $$ \mathcal{L}\{\cos(\frac{t}{2})\} = \frac{s}{s^2 + \frac{1}{4}} $$

# %%
# Define the time domain function:
f7 = sym.cos(t/2)
f7
# Out:
#    ⎛t⎞
# cos⎜─⎟
#    ⎝2⎠

# %%
# Compute the Laplace Transform:
f7s = laplace_transform(f7, t, s, noconds=True)
f7s
# Out:
#   s
# ──────
#  2   1
# s  + ─
#      4
