# %% [markdown]
# - **Name:** Dave DeBien
# - **Term:** 3 AY25-26

# %% [markdown]
# ##### Required Python Packages
# Run the following applications once if they are not yet installed in your Python environment:

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (2.4.5)

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from scipy) (2.4.5)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (2.4.5)
# Requirement already satisfied: packaging>=20.0 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install panda
# Out:
# Requirement already satisfied: panda in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (0.3.1)
# Requirement already satisfied: setuptools in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from panda) (82.0.1)
# Requirement already satisfied: requests in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from panda) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from requests->panda) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from requests->panda) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from requests->panda) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from requests->panda) (2026.4.22)

# %%
# !pip install gekko
# Out:
# Requirement already satisfied: gekko in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (1.3.2)
# Requirement already satisfied: numpy>=1.8 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from gekko) (2.4.5)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from scikit-learn) (2.4.5)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\divin\.conda\envs\control-system-cpe2a\Lib\site-packages (from sympy) (1.3.0)

# %% [markdown]
# ### Machine Problem 002: Inverse Laplace Transforms
#
# Finding a function $f(t)$, given the Laplace transform $F(s)$.  If $L{f(t)} = F(s)$ we write:
#
# $f(t) = \mathcal{L}^{-1}\left(F(s)\right)$
#
# The SymPy library is a symbolic mathematics library written for Python that can be used to perform analytical calculations. This library can be very useful for control system design and analysis.

# %% [markdown]
# ### Table of Common Laplace Transforms
# Mathematicians have developed tables of commonly used Laplace transforms. Here is summary table with a few of the entries that will be most common for analysis of linear differential equations.
#
# | **Item no.** | **f(t)**                | **F(s)**                           |
# |--------------|-------------------------|------------------------------------|
# | 1.           | $ \delta(t) $           | $ 1 $                              |
# | 2.           | $ u(t) $                | $ \frac{1}{s} $                    |
# | 3.           | $ tu(t) $               | $ \frac{1}{s^2} $                  |
# | 4.           | $ t^n u(t) $            | $ \frac{n!}{s^{n+1}} $             |
# | 5.           | $ e^{-at}u(t) $         | $ \frac{1}{s + a} $                |
# | 6.           | $ \sin(\omega t)u(t) $  | $ \frac{\omega}{s^2 + \omega^2} $  |
# | 7.           | $ \cos(\omega t)u(t) $  | $ \frac{s}{s^2 + \omega^2} $       |

# %%
import sympy as sym
from sympy.abc import s,t,u,x,y,z,a,b,c,k
from sympy.integrals import inverse_laplace_transform

# %%
# For pretty  printing
sym.init_printing()

# %%
# Define variables for time 't' and complex variable 's'
# t = sym.symbols('t', real=True)
# s = sym.symbols('s')

# Define a constant:
# a = sym.symbols('a', real=True, positive=True)

# %% [markdown]
# 1. Evaluate:
#
# $$ \mathcal{L}^{-1}\{\frac{2}{s^3}\} = t^2 $$

# %%
# Define the frequency domain function:
f1s = 2/s**3
f1s
# Out:
# 2
# ──
#  3
# s

# %%
# Compute the Inverse Laplace Transform:
f1 = inverse_laplace_transform(f1s, s, t)
f1
# Out:
#  2
# t ⋅θ(t)

# %% [markdown]
# 2. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{s}{s^2+1}= cos(t) $$

# %%
# Define the frequency domain function:
f2s = s/(s**2+1)
f2s
# Out:
#   s
# ──────
#  2
# s  + 1

# %%
# Compute the Inverse Laplace Transform:
f2 = inverse_laplace_transform(f2s, s, t)
f2
# Out:
# cos(t)⋅θ(t)

# %% [markdown]
# 3. Evaluate:
# $$ \mathcal{L}^{-1}\frac{1}{s^2+1}= sin(t) $$

# %%
# Define the frequency domain function:
f3s = 1/(s**2+1)
f3s
# Out:
#   1
# ──────
#  2
# s  + 1

# %%
# Laplace transform (t->s)
f3 = inverse_laplace_transform(f3s, s, t)
f3
# Out:
# sin(t)⋅θ(t)

# %% [markdown]
# 4. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{10}{(s+2)^4}= \frac{5t^3e^{-2t}}{3} $$

# %%
# Define the frequency domain function:

# %%
# Compute the Inverse Laplace Transform:

# %% [markdown]
# 5. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{s+1}{(s+1)^2+4} = e^{-t}cos2t $$

# %%
# Define the frequency domain function:

# %%
# Compute the Inverse Laplace Transform:

# %% [markdown]
# 6. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{15}{(s-1)^2-9} = 5e^{t}sinh3t $$

# %%
# Define the frequency domain function:

# %%
# Compute the Inverse Laplace Transform:

# %% [markdown]
# 7. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{4s-1}{s^2-s}= 1 + 3e^t $$

# %%
# Define the frequency domain function:

# %%
# Compute the Inverse Laplace Transform:
